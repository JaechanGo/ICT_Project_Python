# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(-5,5,0.1)
y1=x**2 -2
y2=20*np.cos(x)**2

plt.figure(1) #1번 그래프 창을 생성
plt.plot(x,y1)# 지정된 그래프 창에 그래프 그림

plt.figure(2) #2번 그래프 창을 생성
plt.plot(x,y2)#지정된 그래프 창에 그래프 그림

plt.figure(1) #이미 생성된 1번 그래프 창을 지정
plt.plot(x,y2)# 지정된 그래프 창에 그래프 그림

plt.figure(2)#이미 생성된 2번 그래프 창을 지정
plt.clf()    # 지정된 그래프 창에 그려진 그래프를 모두 지움
plt.plot(x,y1,'r,-.')# 지정된 그래프 창에 그래프 그림
plt.show()

# %%
import matplotlib.pyplot as plt
 plt.title("line plot")
    
 plt.plot([10, 20, 30, 40], [1, 4, 9, 16], 'bo--')
 plt.show()
# Out:
#   File "<ipython-input-13-8c4eb68d3ed0>", line 2
#     plt.title("line plot")
#     ^
# IndentationError: unexpected indent

# %%
from matplotlib import font_manager
import matplotlib.pyplot as plt
font_location= '/Users/chan/Library/Fonts/BMEULJIRO.otf'
font_name = font_manager.FontProperties(
fname=font_location).get_name()
#font = {'family': font_name, 'color': 'black', 'size': 20}
font = {'family': 'gulim ', 'color': 'black', 'size': 20}
plt.title("라인 플롯(line plot)", fontdict=font)
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c="b", lw=5, ls="--",
marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.xlim(0, 50)
plt.ylim(0, 20)
plt.show()
# Out:
# /Users/chan/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 46972 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/chan/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/chan/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 54540 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/chan/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 47215 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/chan/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 46972 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...
